# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv('Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
print("Shape:", df.shape)
print("\nInfo:\n")
print(df.info())
print("\nMissing values:\n")
print(df.isnull().sum())
# Out:
# Shape: (200, 5)
#
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB
# None
#
# Missing values:
#
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_")

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score_(1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Selecting only the relevant numerical features
features = df[['Age', 'Annual_Income_(k$)', 'Spending_Score_(1-100)']]
features.head()
# Out:
#    Age  Annual_Income_(k$)  Spending_Score_(1-100)
# 0   19                  15                      39
# 1   21                  15                      81
# 2   20                  16                       6
# 3   23                  16                      77
# 4   31                  17                      40

# %%
# Standardizing the features for KMeans
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
scaled_df = pd.DataFrame(scaled_features, columns=features.columns)

# %%
scaled_df
# Out:
#           Age  Annual_Income_(k$)  Spending_Score_(1-100)
# 0   -1.424569           -1.738999               -0.434801
# 1   -1.281035           -1.738999                1.195704
# 2   -1.352802           -1.700830               -1.715913
# 3   -1.137502           -1.700830                1.040418
# 4   -0.563369           -1.662660               -0.395980
# ..        ...                 ...                     ...
# 195 -0.276302            2.268791                1.118061
# 196  0.441365            2.497807               -0.861839
# 197 -0.491602            2.497807                0.923953
# 198 -0.491602            2.917671               -1.250054
# 199 -0.635135            2.917671                1.273347
#
# [200 rows x 3 columns]

# %%
# List to store Within-Cluster Sum of Squares for each k
wcss = []

# Try K values from 1 to 10
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_df)
    wcss.append(kmeans.inertia_)  # inertia_ is the WCSS

# Plot the Elbow curve
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), wcss, marker='o', linestyle='--', color='orange')
plt.title('Elbow Method - Optimal K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.grid(True)
plt.show()

# %%
# Calculate silhouette score for K=2 to 10
silhouette_scores = []

for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(scaled_df)
    score = silhouette_score(scaled_df, kmeans.labels_)
    silhouette_scores.append(score)

# Plot silhouette scores
plt.figure(figsize=(8, 5))
plt.plot(range(2, 11), silhouette_scores, marker='s', linestyle='-', color='green')
plt.title('Silhouette Score for K')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.grid(True)
plt.show()

# %%
# Apply KMeans with the selected optimal number of clusters
optimal_k = 5  # Change if needed
kmeans = KMeans(n_clusters=optimal_k, random_state=42,n_init=10)
kmeans.fit(scaled_df)

# Add cluster labels to original dataset
df['Cluster'] = kmeans.labels_

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score_(1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster
# 0          1
# 1          1
# 2          0
# 3          1
# 4          1
# ...

# %%
# Display cluster-wise summary
df.groupby('Cluster')[['Age', 'Annual_Income_(k$)', 'Spending_Score_(1-100)']].mean().round(2)
# Out:
#            Age  Annual_Income_(k$)  Spending_Score_(1-100)
# Cluster
# 0        46.25               26.75                   18.35
# 1        25.19               41.09                   62.24
# 2        32.88               86.10                   81.53
# 3        39.87               86.10                   19.36
# 4        55.64               54.38                   48.85

# %%
# Reduce dimensions to 2D for plotting
pca = PCA(n_components=2)
pca_data = pca.fit_transform(scaled_df)

# Add PCA results to dataset
df['PCA1'] = pca_data[:, 0]
df['PCA2'] = pca_data[:, 1]

# Plot 2D clusters
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='PCA1', y='PCA2', hue='Cluster', palette='Set2', s=80)
plt.title('Customer Segments Visualized in 2D (PCA)')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.legend(title='Cluster')
plt.show()

# %%
# View statistics per cluster
cluster_summary = df.groupby('Cluster')[['Age', 'Annual_Income_(k$)', 'Spending_Score_(1-100)']].mean().round(1)
cluster_summary
# Out:
#           Age  Annual_Income_(k$)  Spending_Score_(1-100)
# Cluster
# 0        46.2                26.8                    18.4
# 1        25.2                41.1                    62.2
# 2        32.9                86.1                    81.5
# 3        39.9                86.1                    19.4
# 4        55.6                54.4                    48.9

# %%
# Map cluster labels to human-readable customer segments
persona_map = {
    0: "Budget Buyer",
    1: "Luxury Spender",
    2: "Casual Shopper",
    3: "Youth Saver",
    4: "Window Shopper"
}

# this map can be updated based on actual cluster_summary
df['Persona'] = df['Cluster'].map(persona_map)

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual_Income_(k$)  Spending_Score_(1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster      PCA1      PCA2         Persona
# ...

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Persona', palette='Set3', order=df['Persona'].value_counts().index)
plt.title("Customer Persona Distribution")
plt.xlabel("Persona")
plt.ylabel("Number of Customers")
plt.xticks(rotation=15)
plt.grid(axis='y')
plt.tight_layout()
plt.show()
# Out:
# /var/folders/51/zj3k5c090sqdnx3v30jn9x4w0000gq/T/ipykernel_1340/3002027726.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Persona', palette='Set3', order=df['Persona'].value_counts().index)

# %%
import joblib
import os

#os.makedirs('model', exist_ok=True)
# Save KMeans model
joblib.dump(kmeans, 'kmeans_model.pkl')
# Save the scaler used in preprocessing
joblib.dump(scaler, 'scaler.pkl')
print("✅ KMeans model and scaler saved successfully!")
# Out:
# ✅ KMeans model and scaler saved successfully!
